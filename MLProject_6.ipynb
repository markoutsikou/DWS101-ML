# %% [markdown]
# <a href="https://colab.research.google.com/github/markoutsikou/DWS101-ML/blob/main/MLProject_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Import Libraries**

# %%
# !pip install ydata-profiling
import pandas as pd
from ydata_profiling import ProfileReport

# %% [markdown]
# # **Question 1**

# %%
df = pd.read_csv('bankloan.csv', on_bad_lines='skip', engine='python')
profile = ProfileReport(df, title="Bank Loan Report")
profile
# Out:
# ...
#  21%|██        | 11/53 [00:13<01:23,  1.99s/it]

# %% [markdown]
# # **Question 2**
#
# **1.** *loan_amnt:* mean = 14921.108, max = 35000, min = 1000
#
# **2.** Features to drop:
#
# *   Row ID, id, member_id :no value, just ids
# *   Unnamed: 50, 36months, 60months, dti_joint, annual_inc_joint, mths_since_last_major_derog : very high missing values rate
# *   funded_amnt and loan_amnt: exactly the same, so we keep loan_amnt
# *   grade, sub_grade: related to output
# *   title, emp_title: free text so noisy
# *   out_prncp, total_pymnt, total_rec_prncp, total_rec_late_fee, recoveries, collection_recovery_fee, last_pymnt_d, last_pymnt_amnt, next_pymnt_d, last_credit_pull_d: those are all after the load has given features so we don't need them for prediction

# %%
columns_to_drop=['Row ID','member_id', 'Unnamed: 50',  '36months', '60months', 'dti_joint', 'annual_inc_joint', 'mths_since_last_major_derog','funded_amnt', 'loan_amnt', 'grade', 'sub_grade', 'title', 'emp_title', 'out_prncp', 'total_pymnt', 'total_rec_prncp', 'total_rec_late_fee', 'recoveries', 'collection_recovery_fee', 'last_pymnt_d', 'last_pymnt_amnt', 'next_pymnt_d', 'last_credit_pull_d']

df_clean = df.drop(columns=columns_to_drop)
df_clean
